# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from collections import defaultdict
import random
import joblib
import matplotlib.pyplot as plt
import itertools

# %%
def discretize_target(y, n_bins=5):
    bins = np.linspace(min(y), max(y), n_bins + 1)
    labels = list(range(n_bins))
    y_binned = np.digitize(y, bins[:-1], right=False)
    return y_binned, bins, labels

# %%
def compute_bin_accuracy(y_true, y_pred_bins, bins):
    true_bins = np.digitize(y_true, bins[:-1], right=False)
    correct = (true_bins == y_pred_bins)
    return np.mean(correct)

# %%
def evaluate(y_true, y_pred, results, solver_name, label, pred_bins, bins):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    rel_rmse = rmse / np.mean(y_true)
    
    safe_y_true = np.where(y_true == 0, 1e-8, y_true)
    mape = np.mean(np.abs((y_true - y_pred) / safe_y_true)) * 100 
    bin_acc = compute_bin_accuracy(y_true, pred_bins, bins)

    results.append({
        "Solver": solver_name,
        "Dataset": label,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2,
        "Rel_RMSE": rel_rmse,
        "MAPE (%)": mape,
        "BinAccuracy": bin_acc
    })

# %%
def train_q_learning(X_train, y_train, bins, alpha=0.1, gamma=0.9, epsilon=0.2, episodes=100):
    n_actions = len(bins) - 1
    q_table = defaultdict(lambda: np.zeros(n_actions))
    rewards_per_episode = []

    for episode in range(episodes):
        total_reward = 0
        for i in range(len(X_train)):
            state = tuple(np.round(X_train[i], 2))
            if np.random.rand() < epsilon:
                action = np.random.randint(0, n_actions)
            else:
                action = np.argmax(q_table[state])

            pred_val = 0.5 * (bins[action] + bins[action + 1])
            reward = -abs(pred_val - y_train[i])
            total_reward += reward

            q_table[state][action] += alpha * (
                reward + gamma * np.max(q_table[state]) - q_table[state][action]
            )

        rewards_per_episode.append(total_reward)

        if episode % 10 == 0 or episode == episodes - 1:
            print(f"Q-Learning Episode {episode}: Total Reward = {total_reward:.4f}")

            sample_state = tuple(np.round(X_train[0], 2))
            print(f"Q[{sample_state}] = {q_table[sample_state]}")

    # Plot rewards - Just for verification
    # os.makedirs("./debug", exist_ok=True)
    # plt.figure(figsize=(7, 4))
    # plt.plot(rewards_per_episode, label="Episode Reward")
    # plt.xlabel("Episode")
    # plt.ylabel("Total Reward")
    # plt.title("Q-Learning Reward Curve")
    # plt.grid(True)
    # plt.legend()
    # plt.tight_layout()
    # plt.savefig("./debug/q_learning_reward_curve.png")
    # plt.close()

    return q_table

# %%
def train_sarsa(X_train, y_train, bins, alpha=0.1, gamma=0.9, epsilon=0.2, episodes=100):
    n_actions = len(bins) - 1
    q_table = defaultdict(lambda: np.zeros(n_actions))
    rewards_per_episode = []

    for episode in range(episodes):
        total_reward = 0
        for i in range(len(X_train)):
            state = tuple(np.round(X_train[i], 2))
            action = np.random.randint(0, n_actions) if np.random.rand() < epsilon else np.argmax(q_table[state])

            pred_val = 0.5 * (bins[action] + bins[action + 1])
            reward = -abs(pred_val - y_train[i])
            total_reward += reward

            next_state = state  # single step
            next_action = np.random.randint(0, n_actions) if np.random.rand() < epsilon else np.argmax(q_table[next_state])

            q_table[state][action] += alpha * (
                reward + gamma * q_table[next_state][next_action] - q_table[state][action]
            )

        rewards_per_episode.append(total_reward)

        if episode % 10 == 0 or episode == episodes - 1:
            print(f"SARSA Episode {episode}: Total Reward = {total_reward:.4f}")
            sample_state = tuple(np.round(X_train[0], 2))
            print(f"Q[{sample_state}] = {q_table[sample_state]}")

     # Plot rewards - Just for verification
    # os.makedirs("./debug", exist_ok=True)
    # plt.figure(figsize=(7, 4))
    # plt.plot(rewards_per_episode, label="Episode Reward")
    # plt.xlabel("Episode")
    # plt.ylabel("Total Reward")
    # plt.title("SARSA Reward per Episode")
    # plt.grid(True)
    # plt.legend()
    # plt.tight_layout()
    # plt.savefig("./debug/sarsa_reward_curve.png")
    # plt.close()

    return q_table

# %%
def predict_with_q_table(X, q_table, bins):
    preds = []
    pred_bins = []
    for i in range(len(X)):
        state = tuple(np.round(X[i], 2))
        action = np.argmax(q_table[state])
        pred = 0.5 * (bins[action] + bins[action + 1])
        preds.append(pred)
        pred_bins.append(action)
    return preds, pred_bins

# %%
def rl_predict(solver_name, train_file, test_file, val_file, strategy="q_learning"):
    print(f"\n[RL - {strategy.upper()} - Algo: {solver_name}]")

    df_train = pd.read_csv(train_file)
    df_test = pd.read_csv(test_file)
    df_val = pd.read_csv(val_file)
    
    df_train.dropna(inplace=True)
    df_test.dropna(inplace=True)
    df_val.dropna(inplace=True)

    target_cols = ["solution_time", "optimality_gap", "peak_memory"]
    features = [
        "number_of_elements", "capacity", "max_weight", "min_weight", "mean_weight",
        "median_weight", "std_weight", "weight_range", "max_profit", "min_profit", "mean_profit",
        "median_profit", "std_profit", "profit_range", "renting_ratio", "mean_weight_profit_ratio",
        "median_weight_profit_ratio", "capacity_mean_weight_ratio", "capacity_median_weight_ratio",
        "capacity_std_weight_ratio", "std_weight_profit_ratio", "weight_profit_correlation",
        "ram", "cpu_cores"
    ]

    for df in [df_train, df_test, df_val]:
        for col in target_cols:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            df.dropna(subset=[col], inplace=True)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(df_train[features])
    X_test = scaler.transform(df_test[features])
    X_val = scaler.transform(df_val[features])

    results = []

    for target in target_cols:
    
        y_scaler = StandardScaler()
        y_train_scaled = y_scaler.fit_transform(df_train[[target]]).flatten()
        y_test_scaled = y_scaler.transform(df_test[[target]]).flatten()
        y_val_scaled = y_scaler.transform(df_val[[target]]).flatten()

        y_binned, bins, labels = discretize_target(y_train_scaled, n_bins=5)

         # Tune hyperparameters 
        config = tune_rl_hyperparameters(X_train, y_train_scaled, X_val, y_val_scaled, bins, solver_name, target, strategy)
        print(f"Using tuned config for {target}: {config}")

        
        if strategy == "sarsa":
            q_table = train_sarsa(X_train, y_train_scaled, bins,
                                  gamma=config["gamma"],
                                  epsilon=config["epsilon"],
                                  alpha=config["alpha"],
                                  episodes=config["episodes"])
        else:
            q_table = train_q_learning(X_train, y_train_scaled, bins,
                                       gamma=config["gamma"],
                                       epsilon=config["epsilon"],
                                       alpha=config["alpha"],
                                       episodes=config["episodes"])


        
        pred_test_scaled, pred_bins_test = predict_with_q_table(X_test, q_table, bins)
        pred_val_scaled, pred_bins_val = predict_with_q_table(X_val, q_table, bins)
        pred_test = y_scaler.inverse_transform(np.array(pred_test_scaled).reshape(-1, 1)).flatten()
        pred_val = y_scaler.inverse_transform(np.array(pred_val_scaled).reshape(-1, 1)).flatten()
        y_test = y_scaler.inverse_transform(np.array(y_test_scaled).reshape(-1, 1)).flatten()
        y_val = y_scaler.inverse_transform(np.array(y_val_scaled).reshape(-1, 1)).flatten()



        print(f"\nTarget: {target.upper()}")
        print("[Test]")
        evaluate(y_test, pred_test, results, solver_name, f"{target} (Test)", pred_bins_test, bins)
        print("[Val]")
        evaluate(y_val, pred_val, results, solver_name, f"{target} (Val)", pred_bins_val, bins)

        print(f"Accuracy (Test): {compute_bin_accuracy(y_test, pred_bins_test, bins):.4f}")
        print(f"Accuracy (Val) : {compute_bin_accuracy(y_val, pred_bins_val, bins):.4f}")

        # Optionally save model
        # joblib.dump(q_table, f"./models/qtable_{strategy}_{solver_name}_{target}.pkl")

    results_df = pd.DataFrame(results)
    results_file = f"./results_min_kp/rl_{strategy}_eval_results.csv"
    if os.path.exists(results_file):
        results_df.to_csv(results_file, mode='a', index=False, header=False)
    else:
        results_df.to_csv(results_file, index=False)

# %%
def tune_rl_hyperparameters(X_train, y_train, X_val, y_val, bins, solver_name, target, strategy):
   

    gammas = [0.9]
    epsilons = [0.1, 0.01]
    episodes_list = [500, 1000]
    alphas = [0.05, 0.1]

    param_grid = list(itertools.product(gammas, epsilons, episodes_list, alphas))
    best_rmse = float("inf")
    best_config = {}

    all_results = []

    for gamma, epsilon, episodes, alpha in param_grid:
        if strategy == "sarsa":
            q_table = train_sarsa(X_train, y_train, bins, gamma=gamma, epsilon=epsilon,
                                  alpha=alpha, episodes=episodes)
        else:
            q_table = train_q_learning(X_train, y_train, bins, gamma=gamma, epsilon=epsilon,
                                       alpha=alpha, episodes=episodes)

        pred_val_scaled, _ = predict_with_q_table(X_val, q_table, bins)
        y_scaler = StandardScaler().fit(y_train.reshape(-1, 1))
        pred_val = y_scaler.inverse_transform(np.array(pred_val_scaled).reshape(-1, 1)).flatten()
        y_val_orig = y_scaler.inverse_transform(np.array(y_val).reshape(-1, 1)).flatten()

        rmse = np.sqrt(mean_squared_error(y_val_orig, pred_val))
        all_results.append({
            "solver": solver_name,
            "target": target,
            "strategy": strategy,
            "gamma": gamma,
            "epsilon": epsilon,
            "episodes": episodes,
            "alpha": alpha,
            "rmse": rmse
        })

        if rmse < best_rmse:
            best_rmse = rmse
            best_config = {
                "gamma": gamma,
                "epsilon": epsilon,
                "episodes": episodes,
                "alpha": alpha
            }

    # Save tuning results
    df_tuning = pd.DataFrame(all_results)
    os.makedirs("./rl_tuning", exist_ok=True)
    df_tuning.to_csv(f"./rl_tuning/tune_{strategy}_{solver_name}_{target}.csv", index=False)

    return best_config

# %%
def run_rl_models(base_folder, strategies=["q_learning", "sarsa"]):
    for root, dirs, files in os.walk(base_folder):
        for folder in dirs:
            folder_path = os.path.join(root, folder)
            csv_files = os.listdir(folder_path)

            train_file = [f for f in csv_files if f.endswith("_train.csv")]
            test_file = [f for f in csv_files if f.endswith("_test.csv")]
            val_file = [f for f in csv_files if f.endswith("_val.csv")]

            if train_file and test_file and val_file:
                train_fp = os.path.join(folder_path, train_file[0])
                test_fp = os.path.join(folder_path, test_file[0])
                val_fp = os.path.join(folder_path, val_file[0])

                solver_name = folder
                for strategy in strategies:
                    rl_predict(solver_name, train_fp, test_fp, val_fp, strategy=strategy)

# %%
base_folder = "./trainingData/final_td_min" #Specify path to training data
run_rl_models(base_folder)
# Out:
# [Reinforcement Learning - Q_LEARNING - Solver: or_min]
# [Q-Learning] Episode 0: Total Reward = -1877.5997
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.03927458  0.          0.          0.          0.        ]
# [Q-Learning] Episode 10: Total Reward = -1869.5420
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.23272143 -0.23079903 -0.19744237 -0.27652627 -0.35561017]
# [Q-Learning] Episode 20: Total Reward = -3773.4914
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.38402579 -0.57696553 -0.39389754 -0.55166991 -0.70944229]
# [Q-Learning] Episode 30: Total Reward = -4317.9921
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.6053695  -0.69243918 -0.78342393 -0.82543783 -0.70944229]
# [Q-Learning] Episode 40: Total Reward = -3465.5106
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.82015536 -0.92165725 -0.97694919 -0.82543783 -1.06150525]
# [Q-Learning] Episode 50: Total Reward = -2422.4740
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.06270933 -1.03540744 -1.16950682 -1.09783692 -1.06150525]
# [Q-Learning] Episode 60: Total Reward = -2787.6888
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.2308249  -1.26120441 -1.36110166 -1.368874   -1.41180789]
# [Q-Learning] Episode 70: Total Reward = -3828.8901
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.42708008 -1.48425673 -1.55173852 -1.63855591 -1.41180789]
# [Q-Learning] Episode 80: Total Reward = -2809.6093
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.61752072 -1.70557643 -1.7414222  -1.63855591 -1.76035902]
# [Q-Learning] Episode 90: Total Reward = -3420.9989
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.80231907 -1.81540703 -1.93015746 -1.9068894  -2.10073967]
# [Q-Learning] Episode 100: Total Reward = -2735.6560
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.95212838 -2.0334235  -2.11794905 -2.42822441 -2.10073967]
# [Q-Learning] Episode 110: Total Reward = -3357.2456
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.15565266 -2.14161486 -2.30480168 -2.42822441 -2.44584614]
# [Q-Learning] Episode 120: Total Reward = -2426.4771
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.35215955 -2.35637741 -2.49072004 -2.42822441 -2.44584614]
# [Q-Learning] Episode 130: Total Reward = -3897.7236
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.5151924  -2.5689977  -2.49072004 -2.69260956 -2.78922708]
# [Q-Learning] Episode 140: Total Reward = -3420.1074
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.69930259 -2.77949711 -2.67570882 -2.69260956 -2.78922708]
# [Q-Learning] Episode 150: Total Reward = -2527.9482
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.85205047 -2.8839581  -2.85977265 -2.95567278 -3.13089112]
# [Q-Learning] Episode 160: Total Reward = -2704.9443
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.0002728  -3.09131577 -3.04291616 -3.21742069 -3.13089112]
# [Q-Learning] Episode 170: Total Reward = -2636.5876
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.14410368 -3.19012074 -3.22514395 -3.21742069 -3.79439933]
# [Q-Learning] Episode 180: Total Reward = -2822.4135
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.30652942 -3.29252861 -3.4064606  -3.47785986 -3.79439933]
# [Q-Learning] Episode 190: Total Reward = -3336.1956
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.46335483 -3.49581079 -3.58687067 -3.47785986 -3.79439933]
# [Q-Learning] Episode 200: Total Reward = -2804.5511
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.614773   -3.59669021 -3.76637869 -3.73699683 -3.79439933]
# [Q-Learning] Episode 210: Total Reward = -3190.2354
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.74039778 -3.79693839 -3.76637869 -3.99483812 -4.12214059]
# [Q-Learning] Episode 220: Total Reward = -2305.1323
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.90212694 -3.89631217 -3.94498917 -3.99483812 -4.12214059]
# [Q-Learning] Episode 230: Total Reward = -2591.3751
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.01923815 -4.09357161 -4.1227066  -4.2513902  -4.12214059]
# [Q-Learning] Episode 240: Total Reward = -2584.4695
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.15148982 -4.19146223 -4.29953544 -4.2513902  -4.45714006]
# [Q-Learning] Episode 250: Total Reward = -2707.5546
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.27918154 -4.2888634  -4.29953544 -4.50665952 -4.77850902]
# [Q-Learning] Episode 260: Total Reward = -2423.9754
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.40247053 -4.48220714 -4.47456421 -4.50665952 -4.77850902]
# [Q-Learning] Episode 270: Total Reward = -2392.1113
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.5215086  -4.57815458 -4.64963377 -4.76065249 -4.77850902]
# [Q-Learning] Episode 280: Total Reward = -2526.4545
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.63644231 -4.76693955 -4.82250656 -4.76065249 -4.77850902]
# [Q-Learning] Episode 290: Total Reward = -2834.4615
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.76295069 -4.85631511 -4.82250656 -5.0133755  -4.77850902]
# [Q-Learning] Episode 300: Total Reward = -2433.8999
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.86955964 -4.95039201 -4.9958364  -5.0133755  -5.11022665]
# [Q-Learning] Episode 310: Total Reward = -2801.3275
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.00124494 -5.04399852 -4.9958364  -5.0133755  -5.11022665]
# [Q-Learning] Episode 320: Total Reward = -2302.9485
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.07187684 -5.13713701 -5.16829959 -5.73335059 -5.11022665]
# [Q-Learning] Episode 330: Total Reward = -2145.8993
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.18126962 -5.2298098  -5.16829959 -5.73335059 -5.44028568]
# [Q-Learning] Episode 340: Total Reward = -2226.1129
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.2863625  -5.32201922 -5.33990047 -5.73335059 -5.44028568]
# [Q-Learning] Episode 350: Total Reward = -2064.4951
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.37492454 -5.4137676  -5.51064334 -5.73335059 -5.76462875]
# [Q-Learning] Episode 360: Total Reward = -2553.1553
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.48431799 -5.50505724 -5.51064334 -5.73335059 -5.76462875]
# [Q-Learning] Episode 370: Total Reward = -1893.4345
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.57749896 -5.59589043 -5.68053249 -5.73335059 -5.76462875]
# [Q-Learning] Episode 380: Total Reward = -2340.3979
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.67795676 -5.68626945 -5.68053249 -5.73335059 -5.76462875]
# [Q-Learning] Episode 390: Total Reward = -2249.7266
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.74245458 -5.86367799 -5.84957221 -5.98121011 -5.76462875]
# [Q-Learning] Episode 400: Total Reward = -2223.0529
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.82548899 -5.86367799 -5.84957221 -5.98121011 -6.40414325]
# [Q-Learning] Episode 410: Total Reward = -1879.8243
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.90525956 -5.95271807 -6.01776672 -5.98121011 -6.40414325]
# [Q-Learning] Episode 420: Total Reward = -2305.2558
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.9818946  -6.04131296 -6.01776672 -6.22783033 -6.40414325]
# [Q-Learning] Episode 430: Total Reward = -2076.9064
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.05551735 -6.12946487 -6.18512026 -6.22783033 -6.40414325]
# [Q-Learning] Episode 440: Total Reward = -2249.0134
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.13488956 -6.12946487 -6.18512026 -6.22783033 -6.71365189]
# [Q-Learning] Episode 450: Total Reward = -2078.7065
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.20249854 -6.21717602 -6.35163703 -6.22783033 -6.71365189]
# [Q-Learning] Episode 460: Total Reward = -1890.7935
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.26745002 -6.30444862 -6.35163703 -6.47244932 -6.71365189]
# [Q-Learning] Episode 470: Total Reward = -1999.4628
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.32984845 -6.39103795 -6.35163703 -6.47244932 -7.01807778]
# [Q-Learning] Episode 480: Total Reward = -2114.2308
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.3971198  -6.39103795 -6.51732122 -6.47244932 -7.01807778]
# [Q-Learning] Episode 490: Total Reward = -2021.3133
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.45442131 -6.47744124 -6.51732122 -6.71355152 -7.01807778]
# [Q-Learning] Episode 499: Total Reward = -1850.2865
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.49591444 -6.56341251 -6.68038239 -6.71355152 -7.31426892]
# [Q-Learning] Episode 0: Total Reward = -1907.1461
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.07854915  0.          0.          0.          0.        ]
# [Q-Learning] Episode 10: Total Reward = -1803.0719
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.38496901 -0.46383036 -0.76434917 -0.55305254 -0.71122034]
# [Q-Learning] Episode 20: Total Reward = -4045.8027
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-0.75107071 -0.92566687 -0.76434917 -1.10057456 -2.05261233]
# [Q-Learning] Episode 30: Total Reward = -3472.1444
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.16678665 -1.15312715 -1.53495927 -1.64262136 -2.05261233]
# [Q-Learning] Episode 40: Total Reward = -3144.2692
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.55817494 -1.60124665 -1.91449443 -2.1695581  -2.05261233]
# [Q-Learning] Episode 50: Total Reward = -3022.2944
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-1.98594182 -2.04044857 -2.29023423 -2.1695581  -2.05261233]
# [Q-Learning] Episode 60: Total Reward = -2991.7725
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.27357992 -2.66515849 -2.29023423 -2.6843896  -2.74330655]
# [Q-Learning] Episode 70: Total Reward = -2883.9346
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-2.7047677  -2.66515849 -3.01042132 -2.6843896  -2.74330655]
# [Q-Learning] Episode 80: Total Reward = -2312.1810
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.00615358 -3.08318856 -3.01042132 -3.21059824 -3.42709382]
# [Q-Learning] Episode 90: Total Reward = -2787.1619
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.2899024  -3.49289984 -3.37520186 -3.73154481 -3.42709382]
# [Q-Learning] Episode 100: Total Reward = -2351.3172
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.60002497 -3.69468779 -3.73633458 -3.73154481 -4.10404322]
# [Q-Learning] Episode 110: Total Reward = -2252.8302
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-3.88907947 -3.89445787 -4.09385598 -4.2472819  -4.10404322]
# [Q-Learning] Episode 120: Total Reward = -3346.0994
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.1211596  -4.28802489 -4.44780217 -4.2472819  -4.77422313]
# [Q-Learning] Episode 130: Total Reward = -2238.2101
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.40961205 -4.48186159 -4.44780217 -4.75786163 -4.77422313]
# [Q-Learning] Episode 140: Total Reward = -2153.5876
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.64366753 -4.67375992 -4.7982089  -4.75786163 -5.42303192]
# [Q-Learning] Episode 150: Total Reward = -2655.3048
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-4.86182254 -4.86373928 -5.13409296 -5.26333555 -5.42303192]
# [Q-Learning] Episode 160: Total Reward = -2252.5265
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.06515727 -5.2380176  -5.46113324 -5.26333555 -5.42303192]
# [Q-Learning] Episode 170: Total Reward = -2558.0274
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.28068089 -5.42235437 -5.46113324 -5.76375474 -5.42303192]
# [Q-Learning] Episode 180: Total Reward = -2463.5901
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.47955416 -5.60484778 -5.46113324 -5.76375474 -6.08002194]
# [Q-Learning] Episode 190: Total Reward = -2136.8236
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.6409235  -5.78551625 -6.12383385 -5.76375474 -6.08002194]
# [Q-Learning] Episode 200: Total Reward = -2426.8743
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.81196613 -5.96437804 -6.12383385 -6.25916974 -6.08002194]
# [Q-Learning] Episode 210: Total Reward = -2306.6141
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-5.98864601 -6.14145121 -6.12383385 -6.25916974 -6.08002194]
# [Q-Learning] Episode 220: Total Reward = -2331.1662
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.13282522 -6.14145121 -6.45748026 -6.25916974 -6.73044206]
# [Q-Learning] Episode 230: Total Reward = -2043.2935
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.26586583 -6.31675365 -6.45748026 -6.74963058 -6.73044206]
# [Q-Learning] Episode 240: Total Reward = -1925.7919
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.38862834 -6.49030306 -6.45748026 -7.19589566 -6.73044206]
# [Q-Learning] Episode 250: Total Reward = -2042.1722
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.5019068  -6.66211698 -6.78779021 -7.19589566 -6.73044206]
# [Q-Learning] Episode 260: Total Reward = -2054.2149
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.60643389 -6.8225921  -6.78779021 -7.61932851 -6.73044206]
# [Q-Learning] Episode 270: Total Reward = -1844.9953
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.71440601 -6.8225921  -6.78779021 -8.01160274 -6.73044206]
# [Q-Learning] Episode 280: Total Reward = -2004.5074
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.79188612 -6.9873532  -7.11419929 -8.01160274 -7.37435798]
# [Q-Learning] Episode 290: Total Reward = -1818.9666
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.89353078 -6.9873532  -7.11419929 -8.01160274 -7.37435798]
# [Q-Learning] Episode 300: Total Reward = -1722.4399
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-6.98545638 -6.9873532  -7.11419929 -8.01160274 -7.37435798]
# [Q-Learning] Episode 310: Total Reward = -1740.9219
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-7.0606496  -7.15419662 -7.11419929 -8.01160274 -7.37435798]
# [Q-Learning] Episode 320: Total Reward = -1927.9122
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-7.12201084 -7.31166721 -7.43794205 -8.01160274 -7.37435798]
# [Q-Learning] Episode 330: Total Reward = -1889.5897
# Q[(np.float64(-1.08), np.float64(-0.49), np.float64(-0.5), np.float64(-0.11), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(-0.5), np.float64(-0.28), np.float64(-0.43), np.float64(-0.32), np.float64(-0.5), np.float64(-0.5), np.float64(0.68), np.float64(-0.39), np.float64(0.21), np.float64(1.55), np.float64(0.84), np.float64(0.28), np.float64(-0.42), np.float64(0.69), np.float64(-0.76), np.float64(1.0))] = [-7.17180046 -7.46205847 -7.73001357 -8.40707512 -7.37435798]
# [Q-Learning] Episode 340: Total Reward = -1702.8179
# ...
# [Q-Learning] Episode 90: Total Reward = -1595.2268
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.09768344 -1.05744986 -1.09172915 -1.0537474  -1.25692396]
# [Q-Learning] Episode 100: Total Reward = -1731.8611
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.1872878  -1.17826129 -1.18802469 -1.22631137 -1.25692396]
# [Q-Learning] Episode 110: Total Reward = -1720.4319
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.27599835 -1.27619872 -1.28383874 -1.39801252 -1.50455058]
# [Q-Learning] Episode 120: Total Reward = -1533.7597
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.40740777 -1.39052917 -1.37917373 -1.39801252 -1.50455058]
# [Q-Learning] Episode 130: Total Reward = -1425.3003
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.49392262 -1.48321271 -1.56841606 -1.56885517 -1.50455058]
# [Q-Learning] Episode 140: Total Reward = -1523.4290
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.57957449 -1.57360222 -1.66232816 -1.73884361 -1.75093907]
# [Q-Learning] Episode 150: Total Reward = -1498.4960
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.706453   -1.67912135 -1.7557707  -1.73884361 -1.75093907]
# [Q-Learning] Episode 160: Total Reward = -1520.4348
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.78998488 -1.76466187 -1.84874603 -1.9079821  -1.99609562]
# [Q-Learning] Episode 170: Total Reward = -1556.4003
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.87268353 -1.88087344 -1.94125648 -1.9079821  -1.99609562]
# [Q-Learning] Episode 180: Total Reward = -1524.7162
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-1.99518735 -1.96142034 -2.03330438 -2.0762749  -1.99609562]
# [Q-Learning] Episode 190: Total Reward = -1399.2522
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.0758391  -2.0554494  -2.12489204 -2.0762749  -2.24002638]
# [Q-Learning] Episode 200: Total Reward = -1454.9317
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.15568635 -2.14669261 -2.21602176 -2.24372624 -2.24002638]
# [Q-Learning] Episode 210: Total Reward = -1319.9476
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.27396632 -2.23523251 -2.30669583 -2.24372624 -2.24002638]
# [Q-Learning] Episode 220: Total Reward = -1373.6331
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.31299937 -2.3211492  -2.39691653 -2.41034031 -2.48273749]
# [Q-Learning] Episode 230: Total Reward = -1389.8690
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.42893142 -2.40452039 -2.48668613 -2.41034031 -2.48273749]
# [Q-Learning] Episode 240: Total Reward = -1299.0305
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.50525658 -2.4854215  -2.48668613 -2.57612132 -2.72423504]
# [Q-Learning] Episode 250: Total Reward = -1404.6709
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.58082039 -2.57678173 -2.57600688 -2.57612132 -2.72423504]
# [Q-Learning] Episode 260: Total Reward = -1258.3327
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.65563045 -2.65257917 -2.66488102 -2.74107343 -2.72423504]
# [Q-Learning] Episode 270: Total Reward = -1398.4811
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.72969429 -2.7257233  -2.7533108  -2.74107343 -2.96452511]
# [Q-Learning] Episode 280: Total Reward = -1244.9350
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.80301933 -2.79710797 -2.84129843 -2.90520077 -2.96452511]
# [Q-Learning] Episode 290: Total Reward = -1247.7104
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.87561296 -2.87772146 -2.92884611 -2.90520077 -2.96452511]
# [Q-Learning] Episode 300: Total Reward = -1242.1081
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-2.94748247 -2.94460281 -3.01595606 -3.06850748 -2.96452511]
# [Q-Learning] Episode 310: Total Reward = -1261.4553
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-3.01863507 -3.02013077 -3.01595606 -3.06850748 -3.20361373]
# [Q-Learning] Episode 320: Total Reward = -1187.8366
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-3.08907794 -3.0827929  -3.10263046 -3.23099765 -3.20361373]
# [Q-Learning] Episode 330: Total Reward = -1252.0487
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-3.15881813 -3.15355615 -3.18887149 -3.23099765 -3.20361373]
# [Q-Learning] Episode 340: Total Reward = -1150.5166
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-3.22786266 -3.21226521 -3.27468132 -3.23099765 -3.4415069 ]
# [Q-Learning] Episode 350: Total Reward = -1189.5933
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-3.29621848 -3.27856435 -3.27468132 -3.39267537 -3.4415069 ]
# [Q-Learning] Episode 360: Total Reward = -1107.1069
# Q[(np.float64(-1.1), np.float64(-0.52), np.float64(-0.53), np.float64(-0.12), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.53), np.float64(-0.54), np.float64(-0.28), np.float64(-0.44), np.float64(-0.32), np.float64(-0.53), np.float64(-0.54), np.float64(0.67), np.float64(-0.37), np.float64(0.2), np.float64(1.52), np.float64(0.82), np.float64(0.28), np.float64(-0.41), np.float64(0.68), np.float64(2.16), np.float64(-1.0))] = [-3.36389245 -3.34257753 -3.36006209 -3.39267537 -3.4415069 ]
